# %%
import matplotlib.pyplot as plt
   
Iteration = [1600 , 1700 , 1800 , 2100 , 2200 , 2300 , 2400 , 2500 , 2600 , 2800 , 2900 , 3000 , 3100 , 3200 , 3300 , 3500 , 3600 , 3800 , 3900 , 4100 , 4200]
Rate      = [88.44, 86.62, 79.95, 87.51, 85.43, 86.91, 87.59, 85.16, 82.49, 83.79, 86.44, 89.99, 86.08, 88.16, 88.15, 89.45, 87.09, 83.67, 84.46, 87.62, 85.05]
  
plt.plot(Iteration, Rate)
plt.title('mAP50')
plt.xlabel('Iteration')
plt.ylabel('Rate')
plt.show()

# %%
# libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
 
# Data
df=pd.DataFrame(
    {'x_values': [1600 , 1700 , 1800 , 2100 , 2200 , 2300 ,
                  2400 , 2500 , 2600 , 2800 , 2900 , 3000 ,
                  3100 , 3200 , 3300 , 3500 , 3600 , 3800 ,
                  3900 , 4100 , 4200],
     'Ok':    [92.09, 92.08, 91.85, 93.12, 93.31, 92.62,
               92.54, 92.78, 90.98, 91.25, 91.94, 92.79,
               93.27, 92.95, 90.68, 93.06, 92.78, 92.45,
               91.48, 92.79, 91.08],
     'Bad':   [88.55, 88.34, 85.60, 86.73, 87.11, 88.51,
               86.07, 86.70, 86.24, 86.79, 87.67, 88.38,
               86.79, 90.18, 89.07, 87.41, 89.13, 82.68,
               84.15, 88.73, 85.37],
     'Wrong': [84.69, 79.44, 62.40, 82.68, 75.86, 79.95,
               84.16, 76.00, 70.24, 73.15, 79.70, 88.81,
               78.18, 81.34, 84.70, 87.88, 79.36, 75.87,
               77.73, 81.33, 78.71],
     'mAP' :  [88.44, 86.62, 79.95, 87.51, 85.43, 86.91,
               87.59, 85.16, 82.49, 83.79, 86.44, 89.99,
               86.08, 88.16, 88.15, 89.45, 87.09, 83.67,
               84.46, 87.62, 85.05]
    }
)
 
# multiple line plots
plt.plot( 'x_values', 'mAP', data=df, marker='', color='blue', linewidth=5)
plt.plot( 'x_values', 'Ok', data=df, marker='', color='green', linewidth=2)
plt.plot( 'x_values', 'Bad', data=df, marker='', color='red', linewidth=2)
plt.plot( 'x_values', 'Wrong', data=df, marker='', color='yellow', linewidth=2, linestyle='dashed')
# show legend
plt.legend()

# show graph
plt.show()
